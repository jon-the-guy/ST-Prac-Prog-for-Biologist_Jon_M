# %% [markdown]
# ### **Im making first Jup Notebook.YAY.**

# %%
print("This is my notebook.")

# %% [markdown]
# # **I love markdown.**
# ## *I really love markdown.*

# %% [markdown]
# Specifying my first variable, called INTEGER, which will have the value 12.

# %%
#set integer = 12
INTEGER=12

# %%
print(INTEGER)
# Out:
# 12

# %%
#set FLOAT_PT equal to 12.0
FLOAT_PT=12.0

# %%
#print both integer and FLOAT_PT
print(INTEGER, FLOAT_PT)
# Out:
# 12 12.0

# %%
#set string to "The integer is 12"
STRING="The integer is"

# %%
print(STRING)
# Out:
# The integer is 12

# %%
#print the integer is 12 using the variable name 
print(STRING, INTEGER)
# Out:
# The integer is 12

# %%
print("The sum is",INTEGER + FLOAT_PT)
# Out:
# The sum is 24.0

# %%
STRING2= 'This is a string.\n\n\n'
STRING3="This is also a string"
print(STRING2)
print(STRING3)
# Out:
# This is a string.
#
#
#
# This is also a string

# %% [markdown]
# Applying methods for the first time

# %%
print(STRING)
# Out:
# The integer is

# %%
print(STRING.title())
# Out:
# The Integer Is

# %%
print(STRING.upper())
# Out:
# THE INTEGER IS

# %%
print(STRING.lower())
# Out:
# the integer is

# %%
print(f"The integer is  {INTEGER}, my favorite integer.".upper())
# Out:
# THE INTEGER IS  12, MY FAVORITE INTEGER.

# %%
#creating 3 variables with values 
FIRST="Jon"
LAST="Meb"
AGE=23

# %%
combined = print(f"My name is {FIRST} {LAST} and I'm {AGE} years old".upper())
# Out:
# MY NAME IS JON MEB AND I'M 23 YEARS OLD

# %% [markdown]
# Creating my very first list, which is analogous to an array in Bash. List, like arrays, are zero-based

# %%
#create list 
STUDENTS=['Sariyah', 'Elie', 'Juhi', 'Kena', 'Lu', 'Caroline', 'Shari', 'Hasita', 'Jon']

# %%
print(STUDENTS[4])
# Out:
# Lu

# %%
#see all students in the list
print(STUDENTS)
# Out:
# ['Sariyah', 'Elie', 'Juhi', 'Kena', 'Lu', 'Caroline', 'Shari', 'Hasita', 'Jon']

# %% [markdown]
# create my first nested list

# %%
#create nested list
MY_NEST=[[1,2,3,4], ['Jon', 'had', 'a', 'dog'], ['Coding', 'is', 'life']]

# %%
#indexing into nested list 
print(MY_NEST[0])
print(MY_NEST[1])
print(MY_NEST[2])
# Out:
# [1, 2, 3, 4]
# ['Jon', 'had', 'a', 'dog']
# ['Coding', 'is', 'life']

# %%
#indexing into indivual element in nested list
MY_NEST[2][2]
# Out:
# 'life'

# %%
#indexing into indiv elemnts in nested list
print("Coding is making me question every last decision ive made in my", MY_NEST [2][2])
# Out:
# Coding is making me question every last decision ive made in my life

# %% [markdown]
# Lists are mutable. We can change things in our list. I want to add elements to my list. I will use a method called append to do this.

# %%
print(STUDENTS)
# Out:
# ['Sariyah', 'Elie', 'Juhi', 'Kena', 'Lu', 'Caroline', 'Shari', 'Hasita', 'Brenna']

# %%
#append method
STUDENTS.append('Brenna')
STUDENTS.append('Jon')
print(STUDENTS)
# Out:
# ['Sariyah', 'Elie', 'Juhi', 'Kena', 'Lu', 'Caroline', 'Shari', 'Hasita', 'Brenna', 'Brenna', 'Jon']

# %% [markdown]
# We can also remove elements from a list. We remove them based on their index using a method called pop. It takes the format listname.pop(#)

# %%
#take someone out of list
print(STUDENTS)
STUDENTS.pop(9)
print(STUDENTS)
# Out:
# ['Sariyah', 'Elie', 'Juhi', 'Kena', 'Lu', 'Caroline', 'Shari', 'Hasita', 'Brenna', 'Jon']
# ['Sariyah', 'Elie', 'Juhi', 'Kena', 'Lu', 'Caroline', 'Shari', 'Hasita', 'Brenna']

# %%
POPPED=STUDENTS.pop(8)
print(POPPED)
print(STUDENTS)
# Out:
# Brenna
# ['Sariyah', 'Elie', 'Juhi', 'Kena', 'Lu', 'Caroline', 'Shari', 'Hasita']

# %% [markdown]
# Sometimes you want to reverse the order of your list. this means put last index first

# %%
STUDENTS.reverse()

# %%
print(STUDENTS)
# Out:
# ['Brenna', 'Hasita', 'Shari', 'Caroline', 'Lu', 'Kena', 'Juhi', 'Elie', 'Sariyah']

# %%
BOLOGNA='oscar' #create new string variable 
BOLOGNA_LIST=[] #creates an empty list

# %%
print(BOLOGNA)
print(BOLOGNA_LIST)
# Out:
# oscar
# []

# %%
#loop through string to create a list
for CHAR in BOLOGNA: #for variable character in variable bologna 
    BOLOGNA_LIST.append(CHAR)
#lose your indent to get out of your loop
print("My bologna has a first name. It's", BOLOGNA_LIST, ".")
# Out:
# My bologna has a first name. It's ['o', 's', 'c', 'a', 'r', 'o', 's', 'c', 'a', 'r'] .

# %%
print(FIRST)
print("The last letter of my name is", FIRST[2])
# Out:
# Jon
# The last letter of my name is n

# %% [markdown]
# slicing is splitting a string into charcater. You can index into a string just like you can index into a list. one or may

# %%
print(FIRST)
print('The Last letter of my name is:',FIRST[])
# Out:
# Jon
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[110], line 2
#       1 print(FIRST)
# ----> 2 print('The Last letter of my name is:',FIRST[5])
#
# IndexError: string index out of range

# %%
#splicing many charctaers from a string at once 
FULLNAME='Brenna Levine'
print(FULLNAME)
NEW_FIRST=FULLNAME [0:6] #charcters 0 through 5
NEW_LAST=FULLNAME [7:13] #charcters 7 throgh 12
print('First name:', NEW_FIRST)
print('Last name:', NEW_LAST)
# Out:
# Brenna Levine
# First name: Brenna
# Last name: Levine

# %%
#create a nested list 
ELEMENTS=[['fluorine', 'F'], 
          ['chlorine', 'Cl'],
          ['bromine', 'Br'], 
          ['hydrogen', 'H'], 
          ['helium', 'He']]

# %%
print(ELEMENTS)
# Out:
# [['fluorine', 'F'], ['chlorine', 'Cl'], ['bromine', 'Br'], ['hydrogen', 'H'], ['helium', 'He']]

# %%
#splice the last 3 list in the nested list (in elements) 
ELEMENTS[-3:]
# Out:
# [['bromine', 'Br'], ['hydrogen', 'H'], ['helium', 'He']]
